# %%
import pandas as pd
import os

# %%
df = pd.read_csv("temp_data.csv")

# %%
df
# Out:
#                 SentAt         StartedAt  Control    Sad  Intrusion  \
# 0     15/03/2017 16:10               NaN      NaN    NaN        NaN
# 1     16/03/2017 09:00               NaN      NaN    NaN        NaN
# 2     16/03/2017 15:12               NaN      NaN    NaN        NaN
# 3     16/03/2017 15:30  16/03/2017 15:30     70.0  42.02      76.74
# 4     16/03/2017 21:30               NaN      NaN    NaN        NaN
# ...                ...               ...      ...    ...        ...
# 1230  29/04/2018 16:00               NaN      NaN    NaN        NaN
# 1231  29/04/2018 22:00               NaN      NaN    NaN        NaN
# 1232  30/04/2018 10:00               NaN      NaN    NaN        NaN
# 1233  30/04/2018 16:00               NaN      NaN    NaN        NaN
# 1234  30/04/2018 22:00               NaN      NaN    NaN        NaN
#
#       Encourage  FunThings  IgotThis  Company  Alone  ...    Out  Eaten  \
# 0           NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 1           NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 2           NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 3         59.38      35.54     81.14      0.0  24.92  ...  66.63  61.97
# 4           NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# ...         ...        ...       ...      ...    ...  ...    ...    ...
# 1230        NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 1231        NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 1232        NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 1233        NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
# 1234        NaN        NaN       NaN      NaN    NaN  ...    NaN    NaN
#
#       Avoid  Useful   Enjoy  Pleas  Pleasant  Unpl  Unpleasant  Remarks
# 0       NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 1       NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 2       NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 3     20.52     41.5  79.85    1.0     50.83   1.0       46.68      NaN
# 4       NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# ...     ...      ...    ...    ...       ...   ...         ...      ...
# 1230    NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 1231    NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 1232    NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 1233    NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
# 1234    NaN      NaN    NaN    NaN       NaN   NaN         NaN      NaN
#
# [1235 rows x 27 columns]

# %%
print(df.shape)
print(df.isna().sum())
print(df.columns)
# Out:
# (1235, 27)
# SentAt             0
# StartedAt        691
# Control          691
# Sad              691
# Intrusion        691
# Encourage        691
# FunThings        691
# IgotThis         691
# Company          691
# Alone            691
# Thoughts         691
# Safe             691
# Appointments     691
# Cancel           691
# Laying           691
# Sleep            691
# Qualitysleep    1072
# Out              691
# Eaten            691
# Avoid            691
# Useful           691
# Enjoy            691
# Pleas            691
# Pleasant        1076
# Unpl             691
# Unpleasant      1211
# Remarks         1087
# dtype: int64
# Index(['SentAt', 'StartedAt', 'Control', 'Sad', 'Intrusion', 'Encourage',
#        'FunThings', 'IgotThis', 'Company', 'Alone', 'Thoughts', 'Safe',
#        'Appointments', 'Cancel', 'Laying', 'Sleep', 'Qualitysleep', 'Out',
#        'Eaten', 'Avoid', 'Useful ', 'Enjoy', 'Pleas', 'Pleasant', 'Unpl',
#        'Unpleasant', 'Remarks'],
#       dtype='object')

# %%
df = df.drop(columns = ['Qualitysleep', 'Pleasant', 'Unpleasant', 'Remarks'])

# %%
#drop all which have all missing except for SentAt
to_drop =  ['StartedAt', 'Control', 'Sad', 'Intrusion', 'Encourage',
       'FunThings', 'IgotThis', 'Company', 'Alone', 'Thoughts', 'Safe',
       'Appointments', 'Cancel', 'Laying', 'Sleep', 'Out',
       'Eaten', 'Avoid', 'Useful ', 'Enjoy', 'Pleas', 'Unpl']

df = df.dropna(subset = to_drop, how = 'any', axis=0)

# %%
print(df.shape)
print(df.isna().sum().sum())
print(df.columns)

# %%
df['SentAt']
#first = 16/03/2017
#last = 27/04/2018
# just over a year in scope
# note that we have 544 obs but not evenly spaces out

# %%
df.head()
